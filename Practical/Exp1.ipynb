# %%
import pandas as pd
# File name
CSV_PATH = "placement_predict_50k.csv"
# Read CSV file
df = pd.read_csv(CSV_PATH)
# 1. Display first 5 rows
print("FIRST 5 ROWS")
print(df.head())
# 2. Display dataset shape
print("\nDATASET SHAPE")
print(df.shape)
# 3. Display column names
print("\nCOLUMN NAMES")
print(df.columns)
# 4. Display data types
print("\nDATA TYPES")
print(df.dtypes)
# 5. Display basic information
print("\nDATASET INFORMATION")
df.info()
# 6. Display statistical summary
print("\nSTATISTICAL SUMMARY")
print(df.describe())
# 7. Check missing values
print("\nMISSING VALUES")
print(df.isnull().sum())
# 8. Check duplicate rows
print("\nDUPLICATE ROWS")
print(df.duplicated().sum())
# 9. Placement status distribution
print("\nPLACEMENT STATUS DISTRIBUTION")
print(df["PlacementStatus"].value_counts())
# 10. Placement status percentage
print("\nPLACEMENT STATUS PERCENTAGE")
print(df["PlacementStatus"].value_counts(normalize=True) * 100)
# Out:
# FIRST 5 ROWS
#    StudentID  Gender       City CollegeTier      Stream Specialisation Hostel  \
# 0          1  Female      Delhi       Tier3          IT    DataScience    Yes
# 1          2    Male    Chennai       Tier2         ECE             AI    Yes
# 2          3  Female  Hyderabad       Tier3         ECE     Networking     No
# 3          4  Female     Jaipur       Tier3         ECE       Embedded     No
# 4          5    Male  Ahmedabad       Tier3  Mechanical    DataScience     No
#
#   HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Certifications  Publications  \
# 0               Yes       6.39       6.84  ...               1             0
# 1                No       5.95       6.74  ...               2             0
# 2                No       7.13       8.11  ...               2             1
# 3                No       9.37       9.97  ...               6             2
# 4                No       8.25       8.99  ...               4             2
#
#    AptitudeTestScore  SoftSkillsRating  CodingTestScore  MockInterviewScore  \
# 0               62.3              6.57             40.6                65.7
# 1               44.0              5.86             40.3                51.8
# 2               73.8              7.50             73.6                67.9
# 3              100.0              9.41             98.7                 NaN
# 4               90.8              9.24             83.1               100.0
#
#    ExtraCurricular  CGPA_Tier  PlacementStatus  IsAnomaly
# 0               No     Medium              0.0        0.0
# 1               No     Medium              0.0        0.0
# 2               No       High              1.0        0.0
# 3               No  Excellent              1.0        0.0
# 4               No  Excellent              1.0        0.0
#
# [5 rows x 31 columns]
#
# DATASET SHAPE
# (30226, 31)
#
# COLUMN NAMES
# Index(['StudentID', 'Gender', 'City', 'CollegeTier', 'Stream',
#        'Specialisation', 'Hostel', 'HistoryOfBacklogs', 'SGPA_Sem1',
#        'SGPA_Sem2', 'SGPA_Sem3', 'SGPA_Sem4', 'SGPA_Sem5', 'SGPA_Sem6',
#        'SGPA_Sem7', 'SGPA_Sem8', 'CGPA', 'AttendancePercent', 'Internships',
#        'Projects', 'Workshops', 'Certifications', 'Publications',
#        'AptitudeTestScore', 'SoftSkillsRating', 'CodingTestScore',
#        'MockInterviewScore', 'ExtraCurricular', 'CGPA_Tier', 'PlacementStatus',
#        'IsAnomaly'],
#       dtype='object')
#
# DATA TYPES
# StudentID               int64
# Gender                 object
# City                   object
# CollegeTier            object
# Stream                 object
# Specialisation         object
# Hostel                 object
# HistoryOfBacklogs      object
# SGPA_Sem1             float64
# SGPA_Sem2             float64
# SGPA_Sem3             float64
# SGPA_Sem4             float64
# SGPA_Sem5             float64
# SGPA_Sem6             float64
# SGPA_Sem7             float64
# SGPA_Sem8             float64
# CGPA                  float64
# AttendancePercent     float64
# Internships             int64
# Projects                int64
# Workshops             float64
# Certifications          int64
# Publications            int64
# AptitudeTestScore     float64
# SoftSkillsRating      float64
# CodingTestScore       float64
# MockInterviewScore    float64
# ExtraCurricular        object
# CGPA_Tier              object
# PlacementStatus       float64
# IsAnomaly             float64
# dtype: object
#
# DATASET INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30226 entries, 0 to 30225
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   StudentID           30226 non-null  int64
#  1   Gender              30226 non-null  object
#  2   City                30226 non-null  object
#  3   CollegeTier         30226 non-null  object
#  4   Stream              30226 non-null  object
#  5   Specialisation      30226 non-null  object
#  6   Hostel              30226 non-null  object
#  7   HistoryOfBacklogs   30226 non-null  object
#  8   SGPA_Sem1           30226 non-null  float64
#  9   SGPA_Sem2           30226 non-null  float64
#  10  SGPA_Sem3           30226 non-null  float64
#  11  SGPA_Sem4           30226 non-null  float64
#  12  SGPA_Sem5           30226 non-null  float64
#  13  SGPA_Sem6           30226 non-null  float64
#  14  SGPA_Sem7           30226 non-null  float64
#  15  SGPA_Sem8           30226 non-null  float64
#  16  CGPA                30226 non-null  float64
#  17  AttendancePercent   30226 non-null  float64
#  18  Internships         30226 non-null  int64
#  19  Projects            30226 non-null  int64
#  20  Workshops           27588 non-null  float64
#  21  Certifications      30226 non-null  int64
#  22  Publications        30226 non-null  int64
#  23  AptitudeTestScore   27785 non-null  float64
#  24  SoftSkillsRating    28132 non-null  float64
#  25  CodingTestScore     28443 non-null  float64
#  26  MockInterviewScore  27232 non-null  float64
#  27  ExtraCurricular     30225 non-null  object
#  28  CGPA_Tier           30225 non-null  object
#  29  PlacementStatus     30225 non-null  float64
#  30  IsAnomaly           30225 non-null  float64
# dtypes: float64(17), int64(5), object(9)
# memory usage: 7.1+ MB
#
# STATISTICAL SUMMARY
#           StudentID     SGPA_Sem1     SGPA_Sem2     SGPA_Sem3     SGPA_Sem4  \
# count  30226.000000  30226.000000  30226.000000  30226.000000  30226.000000
# mean   15113.500000      7.191555      7.224558      7.253174      7.279740
# std     8725.638955      1.055526      1.054056      1.055620      1.054502
# min        1.000000      4.000000      4.000000      4.000000      4.000000
# 25%     7557.250000      6.480000      6.520000      6.540000      6.570000
# 50%    15113.500000      7.200000      7.230000      7.260000      7.280000
# 75%    22669.750000      7.910000      7.940000      7.980000      8.000000
# max    30226.000000     10.000000     10.000000     10.000000     10.000000
#
#           SGPA_Sem5     SGPA_Sem6     SGPA_Sem7     SGPA_Sem8          CGPA  \
# count  30226.000000  30226.000000  30226.000000  30226.000000  30226.000000
# mean       7.311739      7.343639      7.372805      7.403624      7.297579
# std        1.056222      1.052864      1.053600      1.056432      1.003291
# min        4.000000      4.000000      4.000000      4.000000      4.000000
# 25%        6.590000      6.630000      6.660000      6.690000      6.620000
# 50%        7.320000      7.350000      7.380000      7.400000      7.300000
# 75%        8.030000      8.060000      8.090000      8.130000      7.980000
# max       10.000000     10.000000     10.000000     10.000000     10.000000
#
#        ...      Projects     Workshops  Certifications  Publications  \
# count  ...  30226.000000  27588.000000    30226.000000   30226.00000
# mean   ...      2.531794      2.048499        2.250645       0.50665
# std    ...      1.490970      1.370861        1.518903       0.61788
# min    ...      0.000000      0.000000        0.000000       0.00000
# 25%    ...      1.000000      1.000000        1.000000       0.00000
# 50%    ...      3.000000      2.000000        2.000000       0.00000
# 75%    ...      4.000000      3.000000        3.000000       1.00000
# max    ...      8.000000      6.000000        8.000000       3.00000
#
#        AptitudeTestScore  SoftSkillsRating  CodingTestScore  \
# count       27785.000000      28132.000000     28443.000000
# mean           64.796732          6.483670        59.835503
# std            15.965653          1.596711        19.010413
# min             2.300000          0.210000         0.000000
# 25%            54.100000          5.410000        47.000000
# 50%            64.900000          6.490000        60.000000
# 75%            75.700000          7.590000        72.900000
# max           100.000000         10.000000       100.000000
#
#        MockInterviewScore  PlacementStatus     IsAnomaly
# count        27232.000000     30225.000000  30225.000000
# mean            64.894047         0.476030      0.024483
# std             15.958557         0.499433      0.154546
# min              5.200000         0.000000      0.000000
# 25%             54.000000         0.000000      0.000000
# 50%             65.000000         0.000000      0.000000
# 75%             75.800000         1.000000      0.000000
# max            100.000000         1.000000      1.000000
#
# [8 rows x 22 columns]
#
# MISSING VALUES
# StudentID                0
# Gender                   0
# City                     0
# CollegeTier              0
# Stream                   0
# Specialisation           0
# Hostel                   0
# HistoryOfBacklogs        0
# SGPA_Sem1                0
# SGPA_Sem2                0
# SGPA_Sem3                0
# SGPA_Sem4                0
# SGPA_Sem5                0
# SGPA_Sem6                0
# SGPA_Sem7                0
# SGPA_Sem8                0
# CGPA                     0
# AttendancePercent        0
# Internships              0
# Projects                 0
# Workshops             2638
# Certifications           0
# Publications             0
# AptitudeTestScore     2441
# SoftSkillsRating      2094
# CodingTestScore       1783
# MockInterviewScore    2994
# ExtraCurricular          1
# CGPA_Tier                1
# PlacementStatus          1
# IsAnomaly                1
# dtype: int64
#
# DUPLICATE ROWS
# 0
#
# PLACEMENT STATUS DISTRIBUTION
# PlacementStatus
# 0.0    15837
# 1.0    14388
# Name: count, dtype: int64
#
# PLACEMENT STATUS PERCENTAGE
# PlacementStatus
# 0.0    52.397022
# 1.0    47.602978
# Name: proportion, dtype: float64

# %%
from google.colab import drive
drive.mount('/content/drive')
